# %% [markdown]
# Below is a short script to read in a random sample of the image data for the simply business project. Please note that these are only some initial exploratory steps.
#
#
# First: Mount google drive and change to google drive folder. List content. Change to the folder where I have stored the data and will store the jupiter notebook.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)

# %cd /content/drive/MyDrive
# %ls
# %cd 'MSc.-Dissertations/1/Files'
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
#  Constitutionalism/   MSc.-Dissertations/   Sports/
#  GitHub/             'Muse Score'/         'Valuable Questions.gdoc'
# /content/drive/MyDrive/MSc.-Dissertations/1/Files
# classification.ipynb  randomsample.ipynb  Robin.ipynb  street_view.zip

# %% [markdown]
# Set up python packages possibly needed.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import pandas as pd
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# Unzip the data file. Note this only needs to be done once! Hence it is commented out.

# %%
# !unzip -q /content/drive/MyDrive/MSc.-Dissertations/1/Files/street_view.zip 
# %cd street_view
# !ls *\(1\).jpg
# !rm *\(1\).jpg
# %cd ..
# Out:
# classification.ipynb  randomsample.ipynb  street_view
# properties.csv	      Robin.ipynb	  street_view.zip

# %% [markdown]
# Random sample of jpeg files names. Take a small sample initially to check things out.

# %%
# !ls street_view
#count how many files and write the filenames into a file
# !ls street_view -1 | wc -l 
# !ls street_view/*.jpg > flist.txt

# import os

# path = 'C:/Users/Robin/Desktop/MSc.-Dissertations/1/Files/street_view'

# with open('flist.txt', 'w') as f:
#     for file in os.listdir(path):
#         f.write(file + '\n')


flist = list(pd.read_csv('flist.txt', header = None)[0])

# Set seed so sample is reproducible 
random.seed(99)  # set this to an integer value!!!
nsamp = 10
flist_sub = random.sample(flist, nsamp)
flist = flist_sub

print(flist)
# Out:
# 16966
# ['street_view/gsv_c6fba904-e168-4fe7-8851-04d409f3db12.jpg', 'street_view/gsv_bb9597b6-655e-448e-b6a6-79fbe1c26c43.jpg', 'street_view/gsv_621bbc77-62df-40fd-af32-09c779be9958.jpg', 'street_view/gsv_57c8b3a2-33bb-4c67-b1b5-801b644ab851.jpg', 'street_view/gsv_70fb5033-604f-421e-8afc-4ffc4cf0206b.jpg', 'street_view/gsv_7a067fe3-f764-407e-a6b4-99de96eb6743.jpg', 'street_view/gsv_42118ab6-ee09-4c0a-b241-d05807afa745.jpg', 'street_view/gsv_2afe400f-f2e3-4b1a-88fe-5567c7dc84d7.jpg', 'street_view/gsv_7b947570-ae42-418b-a43f-f571b120d93c.jpg', 'street_view/gsv_bcbdc03c-25e2-4fb7-9af7-5bd030592b45.jpg']
